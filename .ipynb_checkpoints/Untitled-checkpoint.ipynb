# %%
os._exit(00)

# %%
import os
from py_module.multi_patch import *

# %%
np.random.seed(2)
test = Multi_Patch(n_patches=2,phen_per_patch=5,resources=np.ones(10),perm=0)

# %%
test.divide_resources()
# Out:
# array([[0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5],
#        [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]])

# %%
test.evolve(n_steps=100, plot=True)
# Out:
# array([3.05031570e-01, 6.76288245e-02, 1.77897959e-01, 3.17134133e-01,
#        1.31711949e-01, 4.12796177e-01, 3.99977584e-06, 3.89764180e-01,
#        6.89730677e-02, 3.07429933e-01])
