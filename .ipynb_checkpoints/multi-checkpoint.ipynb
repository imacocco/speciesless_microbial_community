# %%
os._exit(00)

# %%
import os
from py_module.multi_patch import *

# %%
np.random.seed(1)
max_iter = 100
N_patches = 3
phen_per_patch = 6
resources = np.ones(6)*N_patches
test = Multi_Patch(N_patches, phen_per_patch,resources,perm=0.5,ekpyrosis=True)

# %%
test.evolve_async(n_steps=5000,parallel=4, max_iter=max_iter, plt = False)
# Out:
# relative flux: [0.94537037 0.9662037  0.92546296]
# iter_no: 0
# relative flux: [0.32356054 0.06918204 0.01944009]
# iter_no: 1
# relative flux: [0.10822743 0.13731515 0.01683836]
# iter_no: 2
# relative flux: [0.01880708 0.0869303  0.02775564]
# iter_no: 3
# relative flux: [0.00087847 0.04999156 0.01965699]
# iter_no: 4
# relative flux: [0.00010253 0.02890178 0.01199821]
# iter_no: 5
# relative flux: [0.00075367 0.01681601 0.006273  ]
# iter_no: 6
# relative flux: [0.00061215 0.00920806 0.00212999]
# iter_no: 7
# relative flux: [3.54391190e-05 4.31447140e-03 1.54872429e-03]
# iter_no: 8
# relative flux: [0.00037294 0.0029337  0.00081862]
# iter_no: 9
# relative flux: [1.04717692e-03 2.70830374e-03 1.12824268e-05]
# iter_no: 10
# relative flux: [3.98670016e-04 1.09051277e-03 4.80455183e-05]
# iter_no: 11
# relative flux: [0.00026064 0.00018771 0.00032219]
# iter_no: 12
# relative flux: [4.46996569e-06 2.24417488e-04 1.63626132e-04]
# iter_no: 13
# relative flux: [4.70791475e-05 1.57812732e-04 6.47028030e-05]
# iter_no: 14
# relative flux: [4.26137239e-05 8.60629253e-05 2.95053369e-05]

# %%
plt.figure()
[ test.patches[alpha].print_patch() for alpha in range(test.n_patches) ]
plt.show()

# %%
[ plt.scatter(np.ones(phen_per_patch)*(i+1),test.final_populations[i]) for i in range(N_patches)]
plt.show()

# %%
plt.scatter(np.arange(N_patches*phen_per_patch),test.final_populations)

# %%
mask = test.compute_multi_mask()

# %%
new = Multi_Patch(multi_patch = test, mask = mask)

# %%
new.compute_M_ab()

# %%
new.print_M_ab()

# %%
new.compute_spectrum()

# %%
new.plot_spectrum('linear')

# %%
new.print_eigenpatch()
